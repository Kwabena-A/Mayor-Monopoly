# %%
import pandas as pd
from card import ActionType

# %%
df = pd.read_csv("../data/cards.csv", sep="|")

# %%
df.drop(columns=["tag"], inplace=True)

# %%
df
# Out:
#     id             type       category  \
# 0    1           Chance           move
# 1    2           Chance           move
# 2    3           Chance           move
# 3    4           Chance   move_utility
# 4    5           Chance        move_rr
# 5    6           Chance        move_rr
# 6    7           Chance          money
# 7    8           Chance           item
# 8    9           Chance       move_abs
# 9   10           Chance      move_jail
# 10  11           Chance   money_houses
# 11  12           Chance          money
# 12  13           Chance           move
# 13  14           Chance           move
# 14  15           Chance  money_players
# 15  16           Chance          money
# 16  17           Chance          money
# 17  18  Community Chest           move
# 18  19  Community Chest          money
# 19  20  Community Chest          money
# 20  21  Community Chest          money
# 21  22  Community Chest           item
# 22  23  Community Chest      move_jail
# 23  24  Community Chest  money_players
# 24  25  Community Chest          money
# 25  26  Community Chest          money
# 26  27  Community Chest  money_players
# 27  28  Community Chest          money
# 28  29  Community Chest          money
# 29  30  Community Chest          money
# 30  31  Community Chest          money
# 31  32  Community Chest   money_houses
# 32  33  Community Chest          money
# 33  34  Community Chest          money
#
#                                              name  \
# 0                                   Advance to Go
# 1                        Advance to Illinois Ave.
# 2                    Advance to St. Charles Place
# 3                      Advance to nearest Utility
# 4                     Advance to nearest Railroad
# 5                     Advance to nearest Railroad
# 6                   Bank pays you dividend of $50
# 7                            Get out of Jail Free
# 8                                Go Back 3 Spaces
# 9                                      Go to Jail
# 10                           Make General Repairs
# 11                            Pay poor tax of $15
# 12                Take a trip to Reading Railroad
# 13                   Take a walk on the Boardwalk
# 14    You have been elected Chairman of the Board
# 15                 Your building and loan matures
# 16           You have won a crossword competition
# 17                                  Advance to Go
# 18                       Bank error in your favor
# 19                                  Doctor's Fees
# 20                 From sale of stock you get $50
# 21                           Get out of Jail Free
# 22                                     Go to Jail
# 23                              Grand Opera Night
# 24                           Holiday Fund matures
# 25                              Income Tax Refund
# 26                            It is your Birthday
# 27                         Life Insurance Matures
# 28                      Pay hospital fees of $100
# 29                        Pay school fees of $150
# 30                    Receive $25 consultancy fee
# 31                    Assessed for street repairs
# 32  You have won second prize in a beauty contest
# 33                               You inherit $100
#
#                                           description  effect
# 0                                       Collect $200.       0
# 1                      If you pass Go - collect $200.      24
# 2                      If you pass Go - collect $200.      11
# 3   If Utility is unowned, you may buy it from the...      10
# 4   If Railroad is unowned, you may buy it from th...       2
# 5   If Railroad is unowned, you may buy it from th...       2
# 6                                       You gain $50.      50
# 7   This card may be kept until needed, or traded/...       0
# 8                             You move back 3 spaces.      -3
# 9                Do not pass Go, do not collect $200.      10
# 10  For each house you own, you pay $25 - For each...       0
# 11                                           Pay $15.     -15
# 12                     If you pass Go - collect $200.       5
# 13                        Advance token to Boardwalk.      39
# 14                               Pay each player $50.     -50
# 15                                      Collect $150.     150
# 16                                      Collect $100.     100
# 17                                      Collect $200.       0
# 18                                      Collect $200.     200
# 19                                           Pay $50.     -50
# 20                                       Collect $50.      50
# 21  This card may be kept until needed, or traded/...       0
# 22               Do not pass Go, do not collect $200.      10
# 23  Collect $50 from every player for opening nigh...      50
# 24                                      Receive $100.     100
# 25                                       Collect $20.      20
# 26                      Collect $10 from each player.      10
# 27                                      Collect $100.     100
# 28                                          Pay $100.    -100
# 29                                          Pay $150.    -150
# 30                                        Collect $25      25
# 31  You are assessed for street repairs - $40 per ...       0
# 32                                        Collect $10      10
# 33                                       Collect $100     100

# %%
df_chance = df[df["type"] == "Chance"]
df_community = df[df["type"] == "Community Chest"].reset_index()

# %%
df_community
# Out:
#     index  id             type       category  \
# 0      17  18  Community Chest           move
# 1      18  19  Community Chest          money
# 2      19  20  Community Chest          money
# 3      20  21  Community Chest          money
# 4      21  22  Community Chest           item
# 5      22  23  Community Chest      move_jail
# 6      23  24  Community Chest  money_players
# 7      24  25  Community Chest          money
# 8      25  26  Community Chest          money
# 9      26  27  Community Chest  money_players
# 10     27  28  Community Chest          money
# 11     28  29  Community Chest          money
# 12     29  30  Community Chest          money
# 13     30  31  Community Chest          money
# 14     31  32  Community Chest   money_houses
# 15     32  33  Community Chest          money
# 16     33  34  Community Chest          money
#
#                                              name  \
# 0                                   Advance to Go
# 1                        Bank error in your favor
# 2                                   Doctor's Fees
# 3                  From sale of stock you get $50
# 4                            Get out of Jail Free
# 5                                      Go to Jail
# 6                               Grand Opera Night
# 7                            Holiday Fund matures
# 8                               Income Tax Refund
# 9                             It is your Birthday
# 10                         Life Insurance Matures
# 11                      Pay hospital fees of $100
# 12                        Pay school fees of $150
# 13                    Receive $25 consultancy fee
# 14                    Assessed for street repairs
# 15  You have won second prize in a beauty contest
# 16                               You inherit $100
#
#                                           description  effect
# 0                                       Collect $200.       0
# 1                                       Collect $200.     200
# 2                                            Pay $50.     -50
# 3                                        Collect $50.      50
# 4   This card may be kept until needed, or traded/...       0
# 5                Do not pass Go, do not collect $200.      10
# 6   Collect $50 from every player for opening nigh...      50
# 7                                       Receive $100.     100
# 8                                        Collect $20.      20
# 9                       Collect $10 from each player.      10
# 10                                      Collect $100.     100
# 11                                          Pay $100.    -100
# 12                                          Pay $150.    -150
# 13                                        Collect $25      25
# 14  You are assessed for street repairs - $40 per ...       0
# 15                                        Collect $10      10
# 16                                       Collect $100     100

# %%
def init_list(active_df: pd.DataFrame) -> list:
    output = []
    for x in range(active_df.shape[0]):
        net = active_df.loc[x, "effect"]
        shared = active_df.loc[x, "category"] == "money_player"
        move_to = ""
        if "Advance to " in str(active_df.loc[x, "name"]):
            statement = (active_df.loc[x, "name"])
            if "nearest " in statement:
                move_to = statement[len("Advance to nearest "):]
            else:
                move_to = statement[len("Advance to "):]
            if "Jail" in move_to:
                move_to = "Jail"

            if move_to[-1] == ".":
                move_to = move_to[:-1]

        set_status = ""

        if "Jail" in str(active_df.loc[x, "name"]) != -1:
            set_status = "in jail"

        output.append(ActionType(net, shared, move_to, set_status))
    return output

# %%
chances = init_list(df_chance)
community = init_list(df_community)

# %%
print(*community)
# Out:
#         | Net: 0
#         | Shared: False
#         | Move To: Go
#         | Status:
#
#         | Net: 200
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: -50
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 50
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 0
#         | Shared: False
#         | Move To:
#         | Status: in jail
#
#         | Net: 10
#         | Shared: False
#         | Move To:
#         | Status: in jail
#
#         | Net: 50
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 100
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 20
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 10
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 100
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: -100
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: -150
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 25
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 0
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 10
#         | Shared: False
#         | Move To:
#         | Status:
#
#         | Net: 100
#         | Shared: False
#         | Move To:
#         | Status:
