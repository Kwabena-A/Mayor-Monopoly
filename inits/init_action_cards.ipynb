# %%
import pandas as pd
from card import ActionType
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from card import ActionType
#
# File ~\Documents\Code\Python\Major Monopoly\card\__init__.py:1
# ----> 1 from .space import Space
#       2 from .property_card import PropertyCard
#       3 from .action_card import ActionCard
#
# File ~\Documents\Code\Python\Major Monopoly\card\space.py:1
# ----> 1 from .card import Card
#       3 class Space:
#       4     def __init__(self, location: int, card: Card):
#
# File ~\Documents\Code\Python\Major Monopoly\card\card.py:2
#       1 from abc import ABC, abstractmethod
# ----> 2 from player import Player
#       4 class Card(ABC):
#       5     def __init__(self, name, symbol):
#
# File ~\Documents\Code\Python\Major Monopoly\player\__init__.py:1
# ----> 1 from .player import Player
#
# File ~\Documents\Code\Python\Major Monopoly\player\player.py:2
#       1 import card
# ----> 2 from utils import count_color
#       4 class Player:
#       5     def __init__(self, name: str, board_spaces):
#
# File ~\Documents\Code\Python\Major Monopoly\utils\__init__.py:2
#       1 from .display_board import display_board
# ----> 2 from.count_colors import count_color
#
# File ~\Documents\Code\Python\Major Monopoly\utils\count_colors.py:3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("data/board.csv")
#       4 def count_color(color: str) -> int:
#       5     return (df[df["Color"] == color]).shape[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/board.csv'

# %%
df = pd.read_csv("../data/cards.csv", sep="|")

# %%
df.drop(columns=["tag"], inplace=True)

# %%
df
# Out:
#     id             type       category  \
# 0    1           Chance           move
# 1    2           Chance           move
# 2    3           Chance           move
# 3    4           Chance   move_utility
# 4    5           Chance        move_rr
# 5    6           Chance        move_rr
# 6    7           Chance          money
# 7    8           Chance           item
# 8    9           Chance       move_abs
# 9   10           Chance      move_jail
# 10  11           Chance   money_houses
# 11  12           Chance          money
# 12  13           Chance           move
# 13  14           Chance           move
# 14  15           Chance  money_players
# 15  16           Chance          money
# 16  17           Chance          money
# 17  18  Community Chest           move
# 18  19  Community Chest          money
# 19  20  Community Chest          money
# 20  21  Community Chest          money
# 21  22  Community Chest           item
# 22  23  Community Chest      move_jail
# 23  24  Community Chest  money_players
# 24  25  Community Chest          money
# 25  26  Community Chest          money
# 26  27  Community Chest  money_players
# 27  28  Community Chest          money
# 28  29  Community Chest          money
# 29  30  Community Chest          money
# 30  31  Community Chest          money
# 31  32  Community Chest   money_houses
# 32  33  Community Chest          money
# 33  34  Community Chest          money
#
#                                              name  \
# 0                                   Advance to Go
# 1                        Advance to Illinois Ave.
# 2                    Advance to St. Charles Place
# 3                      Advance to nearest Utility
# 4                     Advance to nearest Railroad
# 5                     Advance to nearest Railroad
# 6                   Bank pays you dividend of $50
# 7                            Get out of Jail Free
# 8                                Go Back 3 Spaces
# 9                                      Go to Jail
# 10                           Make General Repairs
# 11                            Pay poor tax of $15
# 12                Take a trip to Reading Railroad
# 13                   Take a walk on the Boardwalk
# 14    You have been elected Chairman of the Board
# 15                 Your building and loan matures
# 16           You have won a crossword competition
# 17                                  Advance to Go
# 18                       Bank error in your favor
# 19                                  Doctor's Fees
# 20                 From sale of stock you get $50
# 21                           Get out of Jail Free
# 22                                     Go to Jail
# 23                              Grand Opera Night
# 24                           Holiday Fund matures
# 25                              Income Tax Refund
# 26                            It is your Birthday
# 27                         Life Insurance Matures
# 28                      Pay hospital fees of $100
# 29                        Pay school fees of $150
# 30                    Receive $25 consultancy fee
# 31                    Assessed for street repairs
# 32  You have won second prize in a beauty contest
# 33                               You inherit $100
#
#                                           description  effect
# 0                                       Collect $200.       0
# 1                      If you pass Go - collect $200.      24
# 2                      If you pass Go - collect $200.      11
# 3   If Utility is unowned, you may buy it from the...      10
# 4   If Railroad is unowned, you may buy it from th...       2
# 5   If Railroad is unowned, you may buy it from th...       2
# 6                                       You gain $50.      50
# 7   This card may be kept until needed, or traded/...       0
# 8                             You move back 3 spaces.      -3
# 9                Do not pass Go, do not collect $200.      10
# 10  For each house you own, you pay $25 - For each...       0
# 11                                           Pay $15.     -15
# 12                     If you pass Go - collect $200.       5
# 13                        Advance token to Boardwalk.      39
# 14                               Pay each player $50.     -50
# 15                                      Collect $150.     150
# 16                                      Collect $100.     100
# 17                                      Collect $200.       0
# 18                                      Collect $200.     200
# 19                                           Pay $50.     -50
# 20                                       Collect $50.      50
# 21  This card may be kept until needed, or traded/...       0
# 22               Do not pass Go, do not collect $200.      10
# 23  Collect $50 from every player for opening nigh...      50
# 24                                      Receive $100.     100
# 25                                       Collect $20.      20
# 26                      Collect $10 from each player.      10
# 27                                      Collect $100.     100
# 28                                          Pay $100.    -100
# 29                                          Pay $150.    -150
# 30                                        Collect $25      25
# 31  You are assessed for street repairs - $40 per ...       0
# 32                                        Collect $10      10
# 33                                       Collect $100     100

# %%
df.loc[1, "name"]
# Out:
# 'Advance to Illinois Ave.'

# %%
df_chance = df[df["type"] == "Chance"]
df_community = df[df["type"] == "Community Chest"].reset_index()

# %%
df_community

# %%
def init_list(active_df: pd.DataFrame) -> list:
    output = []
    for x in range(active_df.shape[0]):
        net = active_df.loc[x, "effect"]
        shared = active_df.loc[x, "category"] == "money_player"
        move_to = ""
        if "Advance to " in str(active_df.loc[x, "name"]):
            statement = (active_df.loc[x, "name"])
            if "nearest " in statement:
                move_to = statement[len("Advance to nearest "):]
            else:
                move_to = statement[len("Advance to "):]
            if "Jail" in move_to:
                move_to = "Jail"

            if move_to[-1] == ".":
                move_to = move_to[:-1]

        set_status = ""

        if "Jail" in str(active_df.loc[x, "name"]) != -1:
            set_status = "in jail"

        output.append(ActionType(net, shared, move_to, set_status))
    return output

# %%
chances = init_list(df_chance)
community = init_list(df_community)

# %%
print(*community)
