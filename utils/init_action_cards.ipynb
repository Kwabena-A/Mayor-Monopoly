# %%
import pandas as pd
from card import PropertyCard, ActionCard, Space

# %%
df = pd.read_csv("../data/cards.csv", sep="|")

# %%
df
# Out:
#     id    tag             type       category  \
# 0    1  ADVGO           Chance           move
# 1    2  ADVIA           Chance           move
# 2    3  ADVSC           Chance           move
# 3    4  ADVNU           Chance   move_utility
# 4    5  ADVNR           Chance        move_rr
# 5    6  ADVNR           Chance        move_rr
# 6    7  BANKD           Chance          money
# 7    8  GETJF           Chance           item
# 8    9  GOBTS           Chance       move_abs
# 9   10  GOTOJ           Chance      move_jail
# 10  11  GENRP           Chance   money_houses
# 11  12  POORT           Chance          money
# 12  13  ADVRR           Chance           move
# 13  14  ADVBW           Chance           move
# 14  15  CHBRD           Chance  money_players
# 15  16  BALMT           Chance          money
# 16  17  CROSS           Chance          money
# 17  18  ADVGO  Community Chest           move
# 18  19  BANKE  Community Chest          money
# 19  20  DOCTF  Community Chest          money
# 20  21  SALES  Community Chest          money
# 21  22  GETJF  Community Chest           item
# 22  23  GOTOJ  Community Chest      move_jail
# 23  24  GRDON  Community Chest  money_players
# 24  25  HOLFM  Community Chest          money
# 25  26  INCTR  Community Chest          money
# 26  27  YBDAY  Community Chest  money_players
# 27  28  LINSM  Community Chest          money
# 28  29  HOSPF  Community Chest          money
# 29  30  SCHLF  Community Chest          money
# 30  31  CONSF  Community Chest          money
# 31  32  STRRP  Community Chest   money_houses
# 32  33  BEUTP  Community Chest          money
# 33  34  INHRT  Community Chest          money
#
#                                              name  \
# 0                                   Advance to Go
# 1                        Advance to Illinois Ave.
# 2                    Advance to St. Charles Place
# 3                      Advance to nearest Utility
# 4                     Advance to nearest Railroad
# 5                     Advance to nearest Railroad
# 6                   Bank pays you dividend of $50
# 7                            Get out of Jail Free
# 8                                Go Back 3 Spaces
# 9                                      Go to Jail
# 10                           Make General Repairs
# 11                            Pay poor tax of $15
# 12                Take a trip to Reading Railroad
# 13                   Take a walk on the Boardwalk
# 14    You have been elected Chairman of the Board
# 15                 Your building and loan matures
# 16           You have won a crossword competition
# 17                                  Advance to Go
# 18                       Bank error in your favor
# 19                                  Doctor's Fees
# 20                 From sale of stock you get $50
# 21                           Get out of Jail Free
# 22                                     Go to Jail
# 23                              Grand Opera Night
# 24                           Holiday Fund matures
# 25                              Income Tax Refund
# 26                            It is your Birthday
# 27                         Life Insurance Matures
# 28                      Pay hospital fees of $100
# 29                        Pay school fees of $150
# 30                    Receive $25 consultancy fee
# 31                    Assessed for street repairs
# 32  You have won second prize in a beauty contest
# 33                               You inherit $100
#
#                                           description  effect
# 0                                       Collect $200.       0
# 1                      If you pass Go - collect $200.      24
# 2                      If you pass Go - collect $200.      11
# 3   If Utility is unowned, you may buy it from the...      10
# 4   If Railroad is unowned, you may buy it from th...       2
# 5   If Railroad is unowned, you may buy it from th...       2
# 6                                       You gain $50.      50
# 7   This card may be kept until needed, or traded/...       0
# 8                             You move back 3 spaces.      -3
# 9                Do not pass Go, do not collect $200.      10
# 10  For each house you own, you pay $25 - For each...       0
# 11                                           Pay $15.     -15
# 12                     If you pass Go - collect $200.       5
# 13                        Advance token to Boardwalk.      39
# 14                               Pay each player $50.     -50
# 15                                      Collect $150.     150
# 16                                      Collect $100.     100
# 17                                      Collect $200.       0
# 18                                      Collect $200.     200
# 19                                           Pay $50.     -50
# 20                                       Collect $50.      50
# 21  This card may be kept until needed, or traded/...       0
# 22               Do not pass Go, do not collect $200.      10
# 23  Collect $50 from every player for opening nigh...      50
# 24                                      Receive $100.     100
# 25                                       Collect $20.      20
# 26                      Collect $10 from each player.      10
# 27                                      Collect $100.     100
# 28                                          Pay $100.    -100
# 29                                          Pay $150.    -150
# 30                                        Collect $25      25
# 31  You are assessed for street repairs - $40 per ...       0
# 32                                        Collect $10      10
# 33                                       Collect $100     100

# %%
chance_cards = []

for x in range(df.shape[0]):
    if df.loc[x, 'Space'] == "Property":
        card = PropertyCard(**(df.loc[x].to_dict()))
    else:
        ActionCard(df.loc[x, 'Name'], "10", "10")
    board_spaces.append(Space(len(board_spaces), card))
# Out:
# {'Name': 'Mediterranean Avenue', 'Space': 'Property', 'Color': 'Brown', 'Position': 1, 'Price': 60, 'PriceBuild': 50, 'Rent': 2, 'RentBuild1': 10, 'RentBuild2': 30, 'RentBuild3': 90, 'RentBuild4': 160, 'RentBuild5': 250, 'Number': 2}
# {'Name': 'Baltic Avenue', 'Space': 'Property', 'Color': 'Brown', 'Position': 3, 'Price': 60, 'PriceBuild': 50, 'Rent': 4, 'RentBuild1': 20, 'RentBuild2': 60, 'RentBuild3': 180, 'RentBuild4': 320, 'RentBuild5': 450, 'Number': 2}
# {'Name': 'Oriental Avenue', 'Space': 'Property', 'Color': 'LightBlue', 'Position': 6, 'Price': 100, 'PriceBuild': 50, 'Rent': 6, 'RentBuild1': 30, 'RentBuild2': 90, 'RentBuild3': 270, 'RentBuild4': 400, 'RentBuild5': 550, 'Number': 3}
# {'Name': 'Vermont Avenue', 'Space': 'Property', 'Color': 'LightBlue', 'Position': 8, 'Price': 100, 'PriceBuild': 50, 'Rent': 6, 'RentBuild1': 30, 'RentBuild2': 90, 'RentBuild3': 270, 'RentBuild4': 400, 'RentBuild5': 550, 'Number': 3}
# {'Name': 'Connecticut Avenue', 'Space': 'Property', 'Color': 'LightBlue', 'Position': 9, 'Price': 120, 'PriceBuild': 50, 'Rent': 8, 'RentBuild1': 40, 'RentBuild2': 100, 'RentBuild3': 300, 'RentBuild4': 450, 'RentBuild5': 600, 'Number': 3}
# {'Name': 'St. Charles Place', 'Space': 'Property', 'Color': 'Pink', 'Position': 11, 'Price': 140, 'PriceBuild': 100, 'Rent': 10, 'RentBuild1': 50, 'RentBuild2': 150, 'RentBuild3': 450, 'RentBuild4': 625, 'RentBuild5': 750, 'Number': 3}
# {'Name': 'States Avenue', 'Space': 'Property', 'Color': 'Pink', 'Position': 13, 'Price': 140, 'PriceBuild': 100, 'Rent': 10, 'RentBuild1': 50, 'RentBuild2': 150, 'RentBuild3': 450, 'RentBuild4': 625, 'RentBuild5': 750, 'Number': 3}
# {'Name': 'Virginia Avenue', 'Space': 'Property', 'Color': 'Pink', 'Position': 14, 'Price': 160, 'PriceBuild': 100, 'Rent': 12, 'RentBuild1': 60, 'RentBuild2': 180, 'RentBuild3': 500, 'RentBuild4': 700, 'RentBuild5': 900, 'Number': 3}
# {'Name': 'St. James Place', 'Space': 'Property', 'Color': 'Orange', 'Position': 16, 'Price': 180, 'PriceBuild': 100, 'Rent': 14, 'RentBuild1': 70, 'RentBuild2': 200, 'RentBuild3': 550, 'RentBuild4': 750, 'RentBuild5': 950, 'Number': 3}
# {'Name': 'Tennessee Avenue', 'Space': 'Property', 'Color': 'Orange', 'Position': 18, 'Price': 180, 'PriceBuild': 100, 'Rent': 14, 'RentBuild1': 70, 'RentBuild2': 200, 'RentBuild3': 550, 'RentBuild4': 750, 'RentBuild5': 950, 'Number': 3}
# {'Name': 'New York Avenue', 'Space': 'Property', 'Color': 'Orange', 'Position': 19, 'Price': 200, 'PriceBuild': 100, 'Rent': 16, 'RentBuild1': 80, 'RentBuild2': 220, 'RentBuild3': 600, 'RentBuild4': 800, 'RentBuild5': 1000, 'Number': 3}
# {'Name': 'Kentucky Avenue', 'Space': 'Property', 'Color': 'Red', 'Position': 21, 'Price': 220, 'PriceBuild': 150, 'Rent': 18, 'RentBuild1': 90, 'RentBuild2': 250, 'RentBuild3': 700, 'RentBuild4': 875, 'RentBuild5': 1050, 'Number': 3}
# {'Name': 'Indiana Avenue', 'Space': 'Property', 'Color': 'Red', 'Position': 23, 'Price': 220, 'PriceBuild': 150, 'Rent': 18, 'RentBuild1': 90, 'RentBuild2': 250, 'RentBuild3': 700, 'RentBuild4': 875, 'RentBuild5': 1050, 'Number': 3}
# {'Name': 'Illinois Avenue', 'Space': 'Property', 'Color': 'Red', 'Position': 24, 'Price': 240, 'PriceBuild': 150, 'Rent': 20, 'RentBuild1': 100, 'RentBuild2': 300, 'RentBuild3': 750, 'RentBuild4': 925, 'RentBuild5': 1100, 'Number': 3}
# {'Name': 'Atlantic Avenue', 'Space': 'Property', 'Color': 'Yellow', 'Position': 26, 'Price': 260, 'PriceBuild': 150, 'Rent': 22, 'RentBuild1': 110, 'RentBuild2': 330, 'RentBuild3': 800, 'RentBuild4': 975, 'RentBuild5': 1150, 'Number': 3}
# {'Name': 'Ventnor Avenue', 'Space': 'Property', 'Color': 'Yellow', 'Position': 27, 'Price': 260, 'PriceBuild': 150, 'Rent': 22, 'RentBuild1': 110, 'RentBuild2': 330, 'RentBuild3': 800, 'RentBuild4': 975, 'RentBuild5': 1150, 'Number': 3}
# {'Name': 'Marvin Gardens', 'Space': 'Property', 'Color': 'Yellow', 'Position': 29, 'Price': 280, 'PriceBuild': 150, 'Rent': 24, 'RentBuild1': 120, 'RentBuild2': 360, 'RentBuild3': 850, 'RentBuild4': 1025, 'RentBuild5': 1200, 'Number': 3}
# {'Name': 'Pacific Avenue', 'Space': 'Property', 'Color': 'Green', 'Position': 31, 'Price': 300, 'PriceBuild': 200, 'Rent': 26, 'RentBuild1': 130, 'RentBuild2': 390, 'RentBuild3': 900, 'RentBuild4': 1100, 'RentBuild5': 1275, 'Number': 3}
# {'Name': 'North Carolina Avenue', 'Space': 'Property', 'Color': 'Green', 'Position': 32, 'Price': 300, 'PriceBuild': 200, 'Rent': 26, 'RentBuild1': 130, 'RentBuild2': 390, 'RentBuild3': 900, 'RentBuild4': 1100, 'RentBuild5': 1275, 'Number': 3}
