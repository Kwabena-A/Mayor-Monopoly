# %%
import pandas as pd
import numpy as np
from card import PropertyCard

# %%
df = pd.read_csv("../data/board.csv")

# %%
(df.loc[3].to_dict())
# Out:
# {'Name': 'Baltic Avenue',
#  'Space': 'Street',
#  'Color': 'Brown',
#  'Position': 3,
#  'Price': 60,
#  'PriceBuild': 50,
#  'Rent': 4,
#  'RentBuild1': 20,
#  'RentBuild2': 60,
#  'RentBuild3': 180,
#  'RentBuild4': 320,
#  'RentBuild5': 450,
#  'Number': 2}

# %%
PropertyCard(**(df.loc[3].to_dict()))
# Out:
# {'Name': 'Baltic Avenue', 'Space': 'Street', 'Color': 'Brown', 'Position': 3, 'Price': 60, 'PriceBuild': 50, 'Rent': 4, 'RentBuild1': 20, 'RentBuild2': 60, 'RentBuild3': 180, 'RentBuild4': 320, 'RentBuild5': 450, 'Number': 2}
